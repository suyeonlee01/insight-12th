# %% [markdown]
# # **시각화 과제**
# ▶ 앞으로 토나오게(...) 사용할 **그래프 유형을 학습**하는 데에 주안점을 두고 진행해주세요! <br>
# ▶ 기작성된 코드는 실행시키며 그래프 특징을 살펴보아요 :) <br>
# ▶ 미작성된 코드는 output cell을 참고하여 같은 결과가 나오도록 코드를 작성해주세요.

# %%
# 필요한 모듈 import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn")  # matplotlib style 설정

# 사진 파일 불러오기
# !pip install IPython
from IPython.display import Image

# 문법 변경에 의한 경고를 무시
import warnings
warnings.filterwarnings('ignore')

# matplotlib 시각화 결과를 jupyter notebook에서 바로 볼 수 있게 해주는 command
# %matplotlib inline
# Out:
# Requirement already satisfied: IPython in c:\users\kw082\anaconda3\lib\site-packages (7.22.0)
# Requirement already satisfied: pickleshare in c:\users\kw082\anaconda3\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\kw082\anaconda3\lib\site-packages (from IPython) (52.0.0.post20210125)
# Requirement already satisfied: jedi>=0.16 in c:\users\kw082\anaconda3\lib\site-packages (from IPython) (0.17.2)
# Requirement already satisfied: decorator in c:\users\kw082\anaconda3\lib\site-packages (from IPython) (5.0.6)
# Requirement already satisfied: traitlets>=4.2 in c:\users\kw082\anaconda3\lib\site-packages (from IPython) (5.0.5)
# Requirement already satisfied: colorama in c:\users\kw082\anaconda3\lib\site-packages (from IPython) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\kw082\anaconda3\lib\site-packages (from IPython) (3.0.17)
# Requirement already satisfied: backcall in c:\users\kw082\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: pygments in c:\users\kw082\anaconda3\lib\site-packages (from IPython) (2.8.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\kw082\anaconda3\lib\site-packages (from jedi>=0.16->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\kw082\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\kw082\anaconda3\lib\site-packages (from traitlets>=4.2->IPython) (0.2.0)

# %% [markdown]
# ### (0) titanic_set.csv 데이터를 변수 data로 불러오세요.

# %%
# pandas 모듈의 read_csv() 이용하여 코드 작성
data=pd.read_csv("./titanic_set.csv")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span style="background-color:#E6E6FA"> countplot(범주형), histplot(수치형) </span>
# ▶ 데이터의 분포와 빈도를 시각화하는 기본적인 플롯

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=data,x='Survived')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=data,x='Survived',hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(5,4))
sns.histplot(data=data,x="Age",hue='Survived')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### (1) 승선항(Embarked)별 생존여부를 hue파라미터를 이용해 확인해보세요.

# %%
# 코드 작성

data['Survived'] = data['Survived'].astype(int)
f, ax = plt.subplots(1, figsize=(10,6))
sns.countplot(x='Survived', hue='Embarked', data=data, ax=ax)
ax.set_title('Embarked vs Survived')
# Out:
# Text(0.5, 1.0, 'Embarked vs Survived')

# %% [markdown]
# ### (2) 나이대별 생존여부를 hue파라미터를 이용해 확인해보세요.

# %%
plt.figure(figsize=(5,4))
sns.histplot(data=data,x='Age',hue='Survived')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# # <span style="background-color:#E6E6FA"> distplot, kdeplot(커널밀도함수) </span>

# %% [markdown]
# ▶ 히스토그램을 매끄럽게 곡선으로 연결한 그래프 <br>
# ▶ displot 함수의 kde 파라미터에 True를 전달하면 밀도 곡선이 표현됨

# %%
sns.displot(data["Age"],kde=True)

# %%
sns.kdeplot(data["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### (3) displot으로 요금(Fare)의 분포를 확인해보세요.

# %%
# 코드 작성
sns.displot(data['Fare'],kde=True)

# %% [markdown]
# # <span style="background-color:#E6E6FA"> barplot(범주형), pointplot(연속형)</span>
# ▶ x에 따른 y의 평균값을 나타내는 그래프

# %%
sns.barplot(data=data, x='Sex', y='Age', hue="Survived")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
plt.figure(figsize=(18,4))
sns.pointplot(data=data,x='Age',y='Fare',linestyles="")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# ### (4) Pclass 별 생존율을 barplot을 통해 확인해보세요.

# %%
# 코드 작성
survival_rate = data.groupby('Pclass')['Survived'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Pclass', y='Survived', data=survival_rate, palette='viridis')

plt.xlabel('Pclass')
plt.ylabel('Survival Rate')
plt.ylim(0, 1)  
plt.show()

# %% [markdown]
# # <span style="background-color:#E6E6FA"> boxplot</span>
#
# ▶데이터의 중앙값, 사분위수, 그리고 이상치를 시각적으로 표현하는 그래프

# %%
sns.boxplot(data=data, x='Pclass', y='Age')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # <span style="background-color:#E6E6FA"> scatterplot</span>
#
# ▶ 데이터를 점으로 찍어 분포를 보는 산점도 그래프 <br>
# ▶ 두 연속변수간의 상관관계를 확인할 때 유용함

# %%
sns.scatterplot(data=data, x="Age",y='Fare',hue="Survived",  
                size='Pclass', sizes=(50,330))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# # <span style="background-color:#E6E6FA"> regplot</span>
#
# ▶ 회귀선이 추가된 산점도 그래프 <br>
# ▶ 두 개의 연속 변수 사이의 산점도를 그리고 선형회귀분석에 의한 회귀선을 함께 나타냄

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.regplot(x='Age',y='Fare',data=data,ax=ax1) ## 회귀선 있는 버전
sns.regplot(x='Age',y='Fare',data=data, ax=ax2, fit_reg=False) ## 회귀선 없는 버전

plt.show()

# %% [markdown]
# # <span style="background-color:#E6E6FA"> pieplot</span>
#
# ▶ 데이터의 비율을 시각적으로 표현하는 데 사용

# %%
embarked_counts = data['Embarked'].value_counts()
plt.pie(embarked_counts, labels=embarked_counts.index, 
        autopct='%1.1f%%', startangle=140)
plt.title("Embarked")
# Out:
# Text(0.5, 1.0, 'Embarked')

# %% [markdown]
# ### (5) Pclass를 파이플롯으로 나타내보세요.

# %%
# 'embarked_counts'에 새로운 값을 할당하여 코드 작성
embarked_counts = data['Pclass'].value_counts()
plt.pie(embarked_counts, labels=embarked_counts.index, 
        autopct='%1.1f%%', startangle=140)
plt.title("Pclass")
# Out:
# Text(0.5, 1.0, 'Pclass')

# %% [markdown]
# # <span style="background-color:#E6E6FA"> heatmap</span>
#
# ▶ 변수간 상관계수를 직관적 볼 수 있는 그래프 <br>
# ▶ corr()함수로 변수간의 상관계수를 구하고 이를 히트맵에 표현할 수 있음

# %% [markdown]
# ### (6) 수치형 변수만 모아 새로운 데이터 프레임을 만들고 히트맵을 찍어보겠습니다.

# %%
df= data[['SibSp','Parch','Age', 'Fare']]
sns.heatmap(df.corr(),annot=True) 
#annot 파라미터는 상관계수 표시 여부 결정
# Out:
# <AxesSubplot:>

# %%
data['Age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # <span style="background-color:#E6E6FA"> catplot</span>
#
# ▶ 범주형 데이터와 연속형 데이터를 함께 시각화할 수 있음

# %%
sns.catplot(x='Pclass', y='Fare', hue='Sex', data=data)

# %% [markdown]
# # <span style="background-color:#E6E6FA"> 여러 개의 플롯 결합 </span>
#
# ▶ 여러 개의 그래프를 찍는 공식 <br>
# f, ax = plt.subplots(1, 2, figsize=(12, 4))
#
# ▶ f는 도화지, ax는 만화를 그릴 때의 하나의 컷!
# 즉, 도화지를 1행 2열로 쪼개겠다는 의미이고 figsize는 도화지의 크기임

# %%
f, ax = plt.subplots(1,2,figsize=(12, 4))  # 1행 2열의 서브플롯 생성
sns.countplot(x='Pclass', data=data, ax=ax[0])  # countplot 사용
ax[0].set_title('Count of Passengers by Pclass')

# 성별에 따른 나이 분포 시각화
sns.barplot(x='Sex', y='Age', data=data, hue='Survived', ax=ax[1])
ax[1].set_title('Age Distribution by Sex and Survival Status')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Sex and Survival Status')

# %% [markdown]
# # <span style="background-color:#E6E6FA"> pairplot</span>
#
# ▶ 다변량 데이터셋에서 각 변수 쌍 간의 관계를 시각적으로 표현하는 그래프 <br>
# ▶ 변수 간의 분포와 상관관계를 파악하는 데 사용함

# %%
sns.pairplot(data=data, hue="Survived")

# %% [markdown]
# # <span style="background-color:#E6E6FA"> 직접 찍어보기</span>

# %% [markdown]
# ### (7) 그래프를 그릴 2x2칸을 설정해보세요.

# %%
# 2행 2열의 서브플롯 생성
f, ax = plt.subplots(2, 2, figsize=(12, 4))

# %% [markdown]
# ### (8) 1행 1열에 승선항(Embarked)별 승객의 수를 알 수 있는 시각화를 진행해보세요.
#
# Q. 승객이 많은 승선항 순으로 나열하면? <br>
# A. S ⇒ C ⇒ Q

# %%
embarked_counts = data['Embarked'].value_counts()

ax[0, 0].bar(embarked_counts.index, embarked_counts.values, color='skyblue')
ax[0, 0].set_title('승선항(Embarked)별 승객 수')
ax[0, 0].set_xlabel('승선항')
ax[0, 0].set_ylabel('승객 수')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### (9) 2행 2열에 객실 등급(Pclass)에 따른 생존율을 알아 볼 수 있는 시각화를 진행해보세요.
#
# Q. 생존률이 가장 높은 등급은? <BR>
# A. 1

# %%
survival_rate = data.groupby('Pclass')['Survived'].mean().reset_index()
ax[1, 1].bar(survival_rate['Pclass'], survival_rate['Survived'], color='red')
ax[1, 1].set_title('객실등급(Pclass)에 따른 생존율')

ax[1, 1].set_xlabel('Pclass')
ax[1, 1].set_ylabel('생존률')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### (10) 나머지 칸에 본인이 파악하고 싶은 정보를 자유롭게 시각화하고, 인사이트를 작성해보세요.
#
# Q. 알아낸 것은? <BR>
#
# A1. <BR> 남성대비 여자의 생존율이 높다.
# A2. <BR>등급이 좋을수록 생존율이 높다.

# %% [markdown]
# ### 수고하셨습니다! 시각화가 필요할 때 두고두고 유용한 자료가 될 테니 잘 보관해주셔요🙌🙌
