# %% [markdown]
# # **시각화 과제**
# ▶ 앞으로 토나오게(...) 사용할 **그래프 유형을 학습**하는 데에 주안점을 두고 진행해주세요! <br>
# ▶ 기작성된 코드는 실행시키며 그래프 특징을 살펴보아요 :) <br>
# ▶ 미작성된 코드는 output cell을 참고하여 같은 결과가 나오도록 코드를 작성해주세요.

# %%
# 필요한 모듈 import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-v0_8")  # matplotlib style 설정

# 사진 파일 불러오기
# !pip install IPython
from IPython.display import Image

# 문법 변경에 의한 경고를 무시
import warnings
warnings.filterwarnings('ignore')

# matplotlib 시각화 결과를 jupyter notebook에서 바로 볼 수 있게 해주는 command
# %matplotlib inline
# Out:
# C:\Users\Program\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Requirement already satisfied: IPython in c:\users\program\anaconda3\lib\site-packages (7.29.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\program\anaconda3\lib\site-packages (from IPython) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\program\anaconda3\lib\site-packages (from IPython) (0.18.0)
# Requirement already satisfied: decorator in c:\users\program\anaconda3\lib\site-packages (from IPython) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\program\anaconda3\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\users\program\anaconda3\lib\site-packages (from IPython) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\program\anaconda3\lib\site-packages (from IPython) (3.0.20)
# Requirement already satisfied: pygments in c:\users\program\anaconda3\lib\site-packages (from IPython) (2.15.1)
# Requirement already satisfied: backcall in c:\users\program\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\program\anaconda3\lib\site-packages (from IPython) (0.1.2)
# Requirement already satisfied: colorama in c:\users\program\anaconda3\lib\site-packages (from IPython) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\program\anaconda3\lib\site-packages (from jedi>=0.16->IPython) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\program\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 483, in run
#     installed_versions[distribution.canonical_name] = distribution.version
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_internal\metadata\pkg_resources.py", line 192, in version
#     return parse_version(self._dist.version)
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_vendor\packaging\version.py", line 56, in parse
#     return Version(version)
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_vendor\packaging\version.py", line 202, in __init__
#     raise InvalidVersion(f"Invalid version: '{version}'")
# pip._vendor.packaging.version.InvalidVersion: Invalid version: '4.0.0-unsupported'

# %% [markdown]
# ### (0) titanic_set.csv 데이터를 변수 data로 불러오세요.

# %%
# pandas 모듈의 read_csv() 이용하여 코드 작성
data = pd.read_csv("titanic_set.csv")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span style="background-color:#E6E6FA"> countplot(범주형), histplot(수치형) </span>
# ▶ 데이터의 분포와 빈도를 시각화하는 기본적인 플롯

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=data,x='Survived')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=data,x='Survived',hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
pip install --upgrade seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\program\anaconda3\lib\site-packages (0.11.2)Note: you may need to restart the kernel to use updated packages.
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\program\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\program\anaconda3\lib\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\program\anaconda3\lib\site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\program\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\program\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\program\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\program\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\program\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\program\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\program\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\program\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\program\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\program\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2021.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\program\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six in c:\users\program\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\program\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.6.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 483, in run
#     installed_versions[distribution.canonical_name] = distribution.version
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_internal\metadata\pkg_resources.py", line 192, in version
#     return parse_version(self._dist.version)
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_vendor\packaging\version.py", line 56, in parse
#     return Version(version)
#   File "C:\Users\Program\anaconda3\lib\site-packages\pip\_vendor\packaging\version.py", line 202, in __init__
#     raise InvalidVersion(f"Invalid version: '{version}'")
# pip._vendor.packaging.version.InvalidVersion: Invalid version: '4.0.0-unsupported'

# %%
plt.figure(figsize=(5,4))
sns.histplot(data=data,x="Age",hue='Survived')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### (1) 승선항(Embarked)별 생존여부를 hue파라미터를 이용해 확인해보세요.

# %%
# 코드 작성
plt.figure(figsize=(8,6))
sns.countplot(x='Survived', hue='Embarked', data=data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# ### (2) 나이대별 생존여부를 hue파라미터를 이용해 확인해보세요.

# %%
plt.figure(figsize=(5,4))
sns.histplot(data=data,x='Age',hue='Survived')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# # <span style="background-color:#E6E6FA"> distplot, kdeplot(커널밀도함수) </span>

# %% [markdown]
# ▶ 히스토그램을 매끄럽게 곡선으로 연결한 그래프 <br>
# ▶ displot 함수의 kde 파라미터에 True를 전달하면 밀도 곡선이 표현됨

# %%
sns.displot(data["Age"],kde=True)

# %%
sns.kdeplot(data["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### (3) displot으로 요금(Fare)의 분포를 확인해보세요.

# %%
# 코드 작성
sns.displot(data['Fare'],kde=True)

# %% [markdown]
# # <span style="background-color:#E6E6FA"> barplot(범주형), pointplot(연속형)</span>
# ▶ x에 따른 y의 평균값을 나타내는 그래프

# %%
sns.barplot(data=data, x='Sex', y='Age', hue="Survived")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
plt.figure(figsize=(18,4))
sns.pointplot(data=data,x='Age',y='Fare',linestyles="")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# ### (4) Pclass 별 생존율을 barplot을 통해 확인해보세요.

# %%
# 코드 작성
sns.barplot(data=data, x='Pclass', y='Survived')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# # <span style="background-color:#E6E6FA"> boxplot</span>
#
# ▶데이터의 중앙값, 사분위수, 그리고 이상치를 시각적으로 표현하는 그래프

# %%
sns.boxplot(data=data, x='Pclass', y='Age')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # <span style="background-color:#E6E6FA"> scatterplot</span>
#
# ▶ 데이터를 점으로 찍어 분포를 보는 산점도 그래프 <br>
# ▶ 두 연속변수간의 상관관계를 확인할 때 유용함

# %%
sns.scatterplot(data=data, x="Age",y='Fare',hue="Survived", 
                size='Pclass', sizes=(50,330))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# # <span style="background-color:#E6E6FA"> regplot</span>
#
# ▶ 회귀선이 추가된 산점도 그래프 <br>
# ▶ 두 개의 연속 변수 사이의 산점도를 그리고 선형회귀분석에 의한 회귀선을 함께 나타냄

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.regplot(x='Age',y='Fare',data=data,ax=ax1) ## 회귀선 있는 버전
sns.regplot(x='Age',y='Fare',data=data, ax=ax2, fit_reg=False) ## 회귀선 없는 버전

plt.show()

# %% [markdown]
# # <span style="background-color:#E6E6FA"> pieplot</span>
#
# ▶ 데이터의 비율을 시각적으로 표현하는 데 사용

# %%
embarked_counts = data['Embarked'].value_counts()
plt.pie(embarked_counts, labels=embarked_counts.index, 
        autopct='%1.1f%%', startangle=140)
plt.title("Embarked")
# Out:
# Text(0.5, 1.0, 'Embarked')

# %% [markdown]
# ### (5) Pclass를 파이플롯으로 나타내보세요.

# %%
# 'embarked_counts'에 새로운 값을 할당하여 코드 작성
embarked_counts = data['Pclass'].value_counts()
plt.pie(embarked_counts, labels=embarked_counts.index, 
        autopct='%1.1f%%', startangle=140)
plt.title("Pclass")
# Out:
# Text(0.5, 1.0, 'Pclass')

# %% [markdown]
# # <span style="background-color:#E6E6FA"> heatmap</span>
#
# ▶ 변수간 상관계수를 직관적 볼 수 있는 그래프 <br>
# ▶ corr()함수로 변수간의 상관계수를 구하고 이를 히트맵에 표현할 수 있음

# %% [markdown]
# ### (6) 수치형 변수만 모아 새로운 데이터 프레임을 만들고 히트맵을 찍어보겠습니다.

# %%
df= data[['SibSp','Parch','Age', 'Fare']]
sns.heatmap(df.corr(),annot=True) 
#annot 파라미터는 상관계수 표시 여부 결정
# Out:
# <AxesSubplot:>

# %%
data['Age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # <span style="background-color:#E6E6FA"> catplot</span>
#
# ▶ 범주형 데이터와 연속형 데이터를 함께 시각화할 수 있음

# %%
sns.catplot(x='Pclass', y='Fare', hue='Sex', data=data)

# %% [markdown]
# # <span style="background-color:#E6E6FA"> 여러 개의 플롯 결합 </span>
#
# ▶ 여러 개의 그래프를 찍는 공식 <br>
# f, ax = plt.subplots(1, 2, figsize=(12, 4))
#
# ▶ f는 도화지, ax는 만화를 그릴 때의 하나의 컷!
# 즉, 도화지를 1행 2열로 쪼개겠다는 의미이고 figsize는 도화지의 크기임

# %%
f, ax = plt.subplots(1, 2, figsize=(12, 4))  # 1행 2열의 서브플롯 생성
sns.countplot(x='Pclass', data=data,ax=ax[0])
sns.barplot(x='Sex', y='Age',data=data, hue="Survived",ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # <span style="background-color:#E6E6FA"> pairplot</span>
#
# ▶ 다변량 데이터셋에서 각 변수 쌍 간의 관계를 시각적으로 표현하는 그래프 <br>
# ▶ 변수 간의 분포와 상관관계를 파악하는 데 사용함

# %%
sns.pairplot(data=data, hue="Survived")

# %% [markdown]
# # <span style="background-color:#E6E6FA"> 직접 찍어보기</span>

# %% [markdown]
# ### (7) 그래프를 그릴 2x2칸을 설정해보세요.

# %%
# 2행 2열의 서브플롯 생성
f, ax = plt.subplots(2, 2, figsize=(12, 4))

# %% [markdown]
# ### (8) 1행 1열에 승선항(Embarked)별 승객의 수를 알 수 있는 시각화를 진행해보세요.
#
# Q. 승객이 많은 승선항 순으로 나열하면? <br>
# A. S ⇒ C ⇒ Q

# %%
# 위 마크다운에 '?' 채우고 코드 작성
f, ax = plt.subplots(2, 2, figsize=(12, 4))
sns.countplot(x='Embarked', data=data, ax=ax[0,0])
plt.show()

# %% [markdown]
# ### (9) 2행 2열에 객실 등급(Pclass)에 따른 생존율을 알아 볼 수 있는 시각화를 진행해보세요.
#
# Q. 생존률이 가장 높은 등급은? <BR>
# A. ?

# %%
# 위 마크다운에 '?' 채우고 코드 작성
f, ax = plt.subplots(2, 2, figsize=(12, 4))
sns.barplot(x='Pclass', y='Survived', data=data, ax=ax[1,1])
plt.show()

# %% [markdown]
# ### (10) 나머지 칸에 본인이 파악하고 싶은 정보를 자유롭게 시각화하고, 인사이트를 작성해보세요.
#
# Q. 알아낸 것은? <BR>
# A1. 남성에 비해 여성이 부모 혹은 자식과 동승한 비율이 높다.<BR>
# A2. 죽은 여성들은 부모나 자식이 있을 확률이 매우 높다.<BR>
# A3. Q 승강장에서 탑승한 사람들은 높은 요금을 내고 탑승한 비율이 다른 승강장에 비해 확연히 적다.<BR>

# %%
# 자유롭게 코드 작성
f, ax = plt.subplots(2, 2, figsize=(12, 4))
sns.countplot(x='Embarked', data=data, ax=ax[0,0])
sns.barplot(x='Sex', y='Parch', hue='Survived', data=data, ax=ax[0,1])
sns.boxplot(x='Fare', y='Embarked', data=data, ax=ax[1,0])
sns.barplot(x='Pclass', y='Survived', data=data, ax=ax[1,1])
plt.show()

# %% [markdown]
# ### 수고하셨습니다! 시각화가 필요할 때 두고두고 유용한 자료가 될 테니 잘 보관해주셔요🙌🙌
